# %% [markdown]
# # Check Seattle air bnb data
# [Data url](http://insideairbnb.com/get-the-data/)

# %%
import pandas as pd
path = 'data/Seattle/'
df_rev1 = pd.read_csv(path+'reviews1.csv')
df_rev2 = pd.read_csv(path+'reviews2.csv')
df_nei = pd.read_csv(path+'neighbourhoods.csv')
df_lis1 = pd.read_csv(path+'listings1.csv')
df_lis2 = pd.read_csv(path+'listings2.csv')
df_cal = pd.read_csv(path+'calendar.csv')

# %%
print(df_rev1.shape)
df_rev1.head()
# Out:
# (306868, 2)
#    listing_id        date
# 0        2318  2008-09-15
# 1        2318  2017-01-10
# 2        2318  2017-04-01
# 3        2318  2017-04-25
# 4        2318  2017-06-18

# %%
print(df_rev2.shape)
df_rev2.head()
# Out:
# (306868, 6)
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0        2318        146  2008-09-15         2451         Kevin
# 1        2318  126302712  2017-01-10     12332845       Jessica
# 2        2318  140977084  2017-04-01      4789466          Ivan
# 3        2318  147262504  2017-04-25     55817131          Mike
# 4        2318  161806368  2017-06-18    113604590          Pete
#
#                                             comments
# 0        1000 times better than staying at a hotel.
# 1  Our family (two couples, a two year old and an...
# 2  Top of the list locations we have stayed at! T...
# 3  SUCH an awesome place. Very clean, quiet and s...
# 4  We flew quite a distance to be at our only dau...

# %%
print(df_nei.shape)
df_nei.head()
# Out:
# (90, 2)
#   neighbourhood_group     neighbourhood
# 0             Ballard             Adams
# 1             Ballard     Loyal Heights
# 2             Ballard       Sunset Hill
# 3             Ballard     West Woodland
# 4             Ballard  Whittier Heights

# %%
print(df_lis1.shape)
df_lis1.head()
# Out:
# (4883, 18)
#      id                                               name  host_id  \
# 0  2318  Casa Madrona - Urban Oasis 1 block from the park!     2536
# 1  6606                Fab, private seattle urban cottage!    14942
# 2  9419                Glorious sun room w/ memory foambed    30559
# 3  9531                The Adorable Sweet Orange Craftsman    31481
# 4  9534                   The Coolest Tangerine Dream MIL!    31481
#
#    host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Megan         Central Area         Madrona  47.61094 -122.29286
# 1      Joyce  Other neighborhoods     Wallingford  47.65444 -122.33629
# 2  Angielena  Other neighborhoods      Georgetown  47.55017 -122.31937
# 3     Cassie         West Seattle  Fairmount Park  47.55495 -122.38663
# 4     Cassie         West Seattle  Fairmount Park  47.55627 -122.38607
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
print(df_lis2.shape)
for col in df_lis2.columns:
    print(col)
df_lis2.head()
# Out:
# (4883, 74)
# id
# listing_url
# scrape_id
# last_scraped
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# ...

# %%
print(df_cal.shape)
df_cal.head()
# Out:
# (1781565, 7)
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      789229  2022-03-23         t  $149.00        $149.00              30
# 1      789229  2022-03-24         t  $149.00        $149.00              30
# 2      789229  2022-03-25         t  $169.00        $169.00              30
# 3      789229  2022-03-26         t  $169.00        $169.00              30
# 4      789229  2022-03-27         t  $149.00        $149.00              30
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125
