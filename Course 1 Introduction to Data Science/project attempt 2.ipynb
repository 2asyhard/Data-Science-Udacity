# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def train_model(X, y):
    lm_model = LinearRegression(normalize=True) # Instantiate
    lm_model.fit(X, y) #Fit
    return lm_model

# %%
def import_data(data_path, drop_col=[]):
    df = pd.read_csv(data_path)
    print("Imported dataframe shape: ", df.shape)
    
    # drop specified columns
    df = df.drop(drop_col, axis=1)
    
    # drop column with all nan values
    df = df.dropna(how='all', axis=1)
    print(f"Df now has shape of {df.shape}")
    print(f"Importing df with shape of {df.shape} is complete!!!")
    return df

# %%
def test_with_numeric_columns(df, label_to_predict):
    #Only use quant variables and drop any rows with missing values
    df = df.select_dtypes(include=['int', 'float'])
    print("Dataframe shape with only numeric value columns: ", df.shape)

    df = df.dropna(subset=[label_to_predict], axis=0)
    print(f"Dataframe shape when nan value is dropped in label({label_to_predict}): ", df.shape)

    # replace nan value with mean of column
    df = fill_mean(df)

    #Split into explanatory and response variables
    X = df.drop(label_to_predict, axis=1)
    y = df[label_to_predict]
    
    #Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42) 
    
    model = train_model(X_train, y_train)

    #Predict and score the model
    y_test_preds = model.predict(X_test) 
    print("The r-squared score for the model using only quantitative variables was {} on {} values.".format(r2_score(y_test, y_test_preds), len(y_test)))

# %%
def get_numeric_type_columns(df):
    df_num = df.select_dtypes(include=['int', 'float'])
    df_num_cols = df_num.columns
    print("Numeric columns from this df: ", df_num.shape[1])
    return df_num_cols

# %%
def fill_mean(series):
    # Mean function
    mean = series.mean()
    # Fill the mean
    series = series.fillna(mean, axis=0)
    return series

# %%
def get_object_type_columns(df):
    df_obj = df.select_dtypes(include=['object'])
    df_obj_cols = df_obj.columns
    print("Object columns from this df: ", df_obj.shape[1])
    return df_obj_cols

# %%
def get_multiple_value_columns(df):
    contain_semicolons = df.apply(lambda col: 
                                  col.str.contains(';').any()
                                  if col.dtypes==object
                                  else False)
    df_contain_semicolons = df.loc[:, contain_semicolons]
    multiple_value_columns = df_contain_semicolons.columns
    return multiple_value_columns

# %%
def get_dummy_simple(series, dummy_na=False):
    df = pd.DataFrame()
    try:
        df = pd.get_dummies(series, prefix=series.name, prefix_sep='_', drop_first=False, dummy_na=dummy_na)
    except:
        print(f"Error with get_dummy_simple(), column: {series.name}")
    return df

# %%
def categorize_feature(series):
    series = series.apply(lambda value: list(value.split(';'))
                       if type(value)!=float
                       else float('nan'))
    return pd.get_dummies(series.apply(pd.Series).stack(dropna=False), prefix=series.name, prefix_sep='_').sum(level=0)

# %%
def get_numeric_dict(df):
    df_num_cols = get_numeric_type_columns(df)
    numeric_df_dict = {}
    numeric_df_names_list = []
    for col in df_num_cols:
        df_filled = fill_mean(df[col])
        numeric_df_dict[col] = df_filled
        numeric_df_names_list.append(col)
    return numeric_df_dict, numeric_df_names_list

# %%
def get_dummy_dict(df, multiple_value_columns=[]):
    df_obj_cols = get_object_type_columns(df)
    categorized_df_dict = {}
    categorized_df_names_list = []
    for col in df_obj_cols:
        if col in multiple_value_columns:
            df_dummy = categorize_feature(df[col]) # my method
        else:
            df_dummy = get_dummy_simple(df[col]) # simple method
        categorized_df_dict[col] = df_dummy
        categorized_df_names_list.append(col)
    return categorized_df_dict, categorized_df_names_list

# %% [markdown]
# ## Use simple get dummies function

# %%
# import 2017 dataset
df = import_data('./survey_results_public_2017.csv', ['Respondent', 'ExpectedSalary'])
label_to_predict = 'Salary'
test_with_numeric_columns(df, label_to_predict)
# Out:
# Imported dataframe shape:  (51392, 154)
# Df now has shape of (51392, 152)
# Importing df with shape of (51392, 152) is complete!!!
# Dataframe shape with only numeric value columns:  (51392, 5)
# Dataframe shape when nan value is dropped in label(Salary):  (12891, 5)
# The r-squared score for the model using only quantitative variables was 0.04072431792894726 on 3868 values.

# %%
df = df.dropna(subset=[label_to_predict], axis=0)
Xs = df.drop(label_to_predict, axis=1)
Xs = Xs.dropna(how='all', axis=1)
y = df[label_to_predict]
print(f"df shape: {df.shape}")
print(f"Xs shape: {Xs.shape}")
print(f"y shape: {y.shape}")
# Out:
# df shape: (12891, 152)
# Xs shape: (12891, 145)
# y shape: (12891,)

# %%
numeric_df_dict, numeric_df_names_list = get_numeric_dict(Xs)
multiple_value_columns = get_multiple_value_columns(Xs) # if use my method to get 
categorized_df_dict, categorized_df_names_list = get_dummy_dict(Xs)
# Out:
# Numeric columns from this df:  4
# Object columns from this df:  141

# %%
assert Xs.shape[1] == len(numeric_df_dict)+len(categorized_df_dict)
assert Xs.shape[1] == len(categorized_df_names_list)+len(numeric_df_names_list)

# %%
def check_result(col, df, y):
    print(col)
    print(f"shape: {df.shape}")
    
    X = df      
    #Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42) 
    
    model = train_model(X_train, y_train)

    #Predict and score the model
    y_test_preds = model.predict(X_test) 
    y_train_preds = model.predict(X_train)
    test_score = r2_score(y_test, y_test_preds)
    train_score = r2_score(y_train, y_train_preds)
    print(f"test_score: {test_score}, train_score: {train_score}")
    print('-'*40)
    
    return test_score, train_score

# %%
# rank every columns prediction r2score
rank_test = []
rank_train = []

for col, df_num in numeric_df_dict.items():
    test_score, train_score = check_result(col, df_num.values.reshape(-1,1), y)
    
    rank_test.append([test_score, col])
    rank_train.append([train_score, col])

for col, df_obj in categorized_df_dict.items():   
    test_score, train_score = check_result(col, df_obj, y)
    
    rank_test.append([test_score, col])
    rank_train.append([train_score, col])
# Out:
# CareerSatisfaction
# shape: (12891, 1)
# test_score: 0.02440744353670876, train_score: 0.02511874806277581
# ----------------------------------------
# JobSatisfaction
# shape: (12891, 1)
# test_score: 0.015714880014184307, train_score: 0.013990287390995837
# ----------------------------------------
# HoursPerWeek
# shape: (12891, 1)
# test_score: 0.008116429443099316, train_score: 0.005353632681996512
# ----------------------------------------
# StackOverflowSatisfaction
# shape: (12891, 1)
# test_score: 0.005130504975913497, train_score: 0.005559666137063934
# ----------------------------------------
# Professional
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ProgramHobby
# shape: (12891, 4)
# test_score: 0.0005247655454900801, train_score: 0.0057765601272673495
# ----------------------------------------
# Country
# shape: (12891, 136)
# test_score: -7.709702341110363e+25, train_score: 0.570935821010838
# ----------------------------------------
# University
# shape: (12891, 4)
# test_score: 0.059509865901402725, train_score: 0.0544224472514756
# ----------------------------------------
# EmploymentStatus
# shape: (12891, 2)
# test_score: 0.019032652112208392, train_score: 0.019680973264939228
# ----------------------------------------
# FormalEducation
# shape: (12891, 9)
# test_score: 0.016781040731313368, train_score: 0.02146004172634286
# ----------------------------------------
# MajorUndergrad
# shape: (12891, 16)
# test_score: 0.033774400959650674, train_score: 0.04188434138419572
# ----------------------------------------
# HomeRemote
# shape: (12891, 7)
# test_score: 0.0339319541374008, train_score: 0.04134497377080071
# ----------------------------------------
# CompanySize
# shape: (12891, 10)
# test_score: 0.05192326010693504, train_score: 0.055556882964653886
# ----------------------------------------
# CompanyType
# shape: (12891, 11)
# test_score: 0.10317553831646353, train_score: 0.10236362926073217
# ----------------------------------------
# YearsProgram
# shape: (12891, 21)
# test_score: 0.17681542205634249, train_score: 0.20201034255966033
# ----------------------------------------
# YearsCodedJob
# shape: (12891, 21)
# test_score: 0.20301667135459334, train_score: 0.2311629385849997
# ----------------------------------------
# YearsCodedJobPast
# shape: (12891, 4)
# test_score: -2.280556701905745e-05, train_score: 0.0006237932263345458
# ----------------------------------------
# DeveloperType
# shape: (12891, 960)
# test_score: -1.7802462745793337e+29, train_score: -0.2043008004179152
# ----------------------------------------
# WebDeveloperType
# shape: (12891, 3)
# test_score: 0.0017131740201840051, train_score: 0.0027155256767170677
# ----------------------------------------
# MobileDeveloperType
# shape: (12891, 8)
# test_score: 0.0003046795550797343, train_score: 0.0075427645313990155
# ----------------------------------------
# ExCoderReturn
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ExCoder10Years
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ExCoderSkills
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# PronounceGIF
# shape: (12891, 4)
# test_score: 0.019270992154200695, train_score: 0.026805212474406592
# ----------------------------------------
# ProblemSolving
# shape: (12891, 5)
# test_score: 0.0058759198066533624, train_score: 0.005640193683399519
# ----------------------------------------
# BuildingThings
# shape: (12891, 5)
# test_score: 0.008689107131503837, train_score: 0.009525815942812543
# ----------------------------------------
# LearningNewTech
# shape: (12891, 5)
# test_score: -0.0014676983983392677, train_score: 0.0023255682404840217
# ----------------------------------------
# BoringDetails
# shape: (12891, 5)
# test_score: 0.003825684214371239, train_score: 0.00727594475588933
# ----------------------------------------
# JobSecurity
# shape: (12891, 5)
# test_score: -0.002452215567662952, train_score: 0.0011779576819969106
# ----------------------------------------
# DiversityImportant
# shape: (12891, 5)
# test_score: 0.0008939673336939569, train_score: 0.008701883033150004
# ----------------------------------------
# AnnoyingUI
# shape: (12891, 5)
# test_score: 0.01081481111540128, train_score: 0.008403714557044917
# ----------------------------------------
# FriendsDevelopers
# shape: (12891, 5)
# test_score: 0.0012467712615621407, train_score: 0.004213833479101758
# ----------------------------------------
# RightWrongWay
# shape: (12891, 5)
# test_score: 0.026071512406958264, train_score: 0.03192385119710861
# ----------------------------------------
# UnderstandComputers
# shape: (12891, 5)
# test_score: 0.016158598188965367, train_score: 0.01793735269493324
# ----------------------------------------
# SeriousWork
# shape: (12891, 5)
# test_score: -0.0009396045912348772, train_score: 0.0033597345113587362
# ----------------------------------------
# InvestTimeTools
# shape: (12891, 5)
# test_score: -0.00011516121709198579, train_score: 0.0022920127629589837
# ----------------------------------------
# WorkPayCare
# shape: (12891, 5)
# test_score: -0.0005343718528225683, train_score: 0.0013682412808148081
# ----------------------------------------
# KinshipDevelopers
# shape: (12891, 5)
# test_score: 0.0009581774258983211, train_score: 0.004361760118558711
# ----------------------------------------
# ChallengeMyself
# shape: (12891, 5)
# test_score: 0.0015011754323820403, train_score: 0.0017763697178764248
# ----------------------------------------
# CompetePeers
# shape: (12891, 5)
# test_score: 0.007874348428628886, train_score: 0.007937316620847734
# ----------------------------------------
# ChangeWorld
# shape: (12891, 5)
# test_score: 0.0031183890202441944, train_score: 0.003704523656501313
# ----------------------------------------
# JobSeekingStatus
# shape: (12891, 3)
# test_score: 0.016917486655911085, train_score: 0.015133338165649435
# ----------------------------------------
# LastNewJob
# shape: (12891, 5)
# test_score: 0.024080623382848998, train_score: 0.02844492138851551
# ----------------------------------------
# AssessJobIndustry
# shape: (12891, 5)
# test_score: 0.009368675949188332, train_score: 0.005525568403546011
# ----------------------------------------
# AssessJobRole
# shape: (12891, 5)
# test_score: 0.007173911729732474, train_score: 0.0044060727843449055
# ----------------------------------------
# AssessJobExp
# shape: (12891, 5)
# test_score: 0.005293454415994825, train_score: 0.002041276172576545
# ----------------------------------------
# AssessJobDept
# shape: (12891, 5)
# test_score: 0.005823494223578418, train_score: 0.0026171456393433434
# ----------------------------------------
# AssessJobTech
# shape: (12891, 5)
# test_score: 0.007048146730017857, train_score: 0.002553998188946527
# ----------------------------------------
# AssessJobProjects
# shape: (12891, 5)
# test_score: 0.003995470924941014, train_score: 0.001621303396405649
# ----------------------------------------
# AssessJobCompensation
# shape: (12891, 5)
# test_score: 0.009219721479803322, train_score: 0.015193122148975502
# ----------------------------------------
# AssessJobOffice
# shape: (12891, 5)
# test_score: 0.0037333032951430978, train_score: 0.0019018038568759943
# ----------------------------------------
# AssessJobCommute
# shape: (12891, 5)
# test_score: 0.025785821726042046, train_score: 0.02302210357972545
# ----------------------------------------
# AssessJobRemote
# shape: (12891, 5)
# test_score: 0.007809722842033406, train_score: 0.006414287557596876
# ----------------------------------------
# AssessJobLeaders
# shape: (12891, 5)
# test_score: 0.00481179625421102, train_score: 0.001789923139501548
# ----------------------------------------
# AssessJobProfDevel
# shape: (12891, 5)
# test_score: 0.008123150881943264, train_score: 0.00896107394472001
# ----------------------------------------
# AssessJobDiversity
# shape: (12891, 5)
# test_score: 0.005869003987272636, train_score: 0.003278075731828034
# ----------------------------------------
# AssessJobProduct
# shape: (12891, 5)
# test_score: 0.003116889684548485, train_score: 0.0017756857645890856
# ----------------------------------------
# AssessJobFinances
# shape: (12891, 5)
# test_score: 0.004925577798540082, train_score: 0.0034662115815516925
# ----------------------------------------
# ImportantBenefits
# shape: (12891, 2047)
# test_score: -3.038669656748752e+29, train_score: -0.45432784884518873
# ----------------------------------------
# ClickyKeys
# shape: (12891, 2)
# test_score: 0.0009173493809646605, train_score: 0.0009201719340772296
# ----------------------------------------
# JobProfile
# shape: (12891, 280)
# test_score: -1.756481845222238e+28, train_score: 0.07184415657926957
# ----------------------------------------
# ResumePrompted
# shape: (12891, 8)
# test_score: 0.007348218600445988, train_score: 0.009252590135821137
# ----------------------------------------
# LearnedHiring
# shape: (12891, 8)
# test_score: 0.010394993173299616, train_score: 0.013904729404609073
# ----------------------------------------
# ImportantHiringAlgorithms
# shape: (12891, 5)
# test_score: 0.006151073898474579, train_score: 0.00920158875427457
# ----------------------------------------
# ImportantHiringTechExp
# shape: (12891, 5)
# test_score: 0.016662468584125234, train_score: 0.01812199910832213
# ----------------------------------------
# ImportantHiringCommunication
# shape: (12891, 5)
# test_score: 0.026928444070211, train_score: 0.02748299420203615
# ----------------------------------------
# ImportantHiringOpenSource
# shape: (12891, 5)
# test_score: 0.00825146519741693, train_score: 0.005592226389724564
# ----------------------------------------
# ImportantHiringPMExp
# shape: (12891, 5)
# test_score: 0.038759220445147125, train_score: 0.040381960782815196
# ----------------------------------------
# ImportantHiringCompanies
# shape: (12891, 5)
# test_score: 0.0025991960236794176, train_score: 0.004412812375864439
# ----------------------------------------
# ImportantHiringTitles
# shape: (12891, 5)
# test_score: 0.007039877690634522, train_score: 0.010887316147601522
# ----------------------------------------
# ImportantHiringEducation
# shape: (12891, 5)
# test_score: 0.003565683805979991, train_score: 0.004483274912324364
# ----------------------------------------
# ImportantHiringRep
# shape: (12891, 5)
# test_score: 0.0170503305175268, train_score: 0.012779527210053154
# ----------------------------------------
# ImportantHiringGettingThingsDone
# shape: (12891, 5)
# test_score: 0.03299409292136546, train_score: 0.04165277292225322
# ----------------------------------------
# Currency
# shape: (12891, 17)
# test_score: 0.4167738538485196, train_score: 0.4339837071598497
# ----------------------------------------
# Overpaid
# shape: (12891, 5)
# test_score: 0.05663789325191737, train_score: 0.049559190807826115
# ----------------------------------------
# TabsSpaces
# shape: (12891, 3)
# test_score: 0.032320097166636086, train_score: 0.04455488365921256
# ----------------------------------------
# EducationImportant
# shape: (12891, 5)
# test_score: 5.201985759994976e-05, train_score: 0.001228346020224147
# ----------------------------------------
# EducationTypes
# shape: (12891, 357)
# test_score: -2.1356665756947067e+26, train_score: 0.08636347969307256
# ----------------------------------------
# SelfTaughtTypes
# shape: (12891, 743)
# test_score: -5.816602908259116e+28, train_score: -0.06698728997899672
# ----------------------------------------
# TimeAfterBootcamp
# shape: (12891, 9)
# test_score: 0.0026799662850353068, train_score: 0.004903854787498441
# ----------------------------------------
# CousinEducation
# shape: (12891, 602)
# test_score: -4.3761148885353715e+28, train_score: 0.03998949123396933
# ----------------------------------------
# WorkStart
# shape: (12891, 24)
# test_score: 0.01632459814083964, train_score: 0.0245959558867076
# ----------------------------------------
# HaveWorkedLanguage
# shape: (12891, 3445)
# test_score: -1.038210224768874e+30, train_score: -4.184949420640078
# ----------------------------------------
# WantWorkLanguage
# shape: (12891, 4660)
# test_score: -1.4774565559694433e+30, train_score: -4.457075023128196
# ----------------------------------------
# HaveWorkedFramework
# shape: (12891, 201)
# test_score: -8.711297311797091e+27, train_score: -0.2493104844973184
# ----------------------------------------
# WantWorkFramework
# shape: (12891, 319)
# test_score: -1.8545156684166017e+28, train_score: -0.08492431657667288
# ----------------------------------------
# HaveWorkedDatabase
# shape: (12891, 218)
# test_score: -9.543258523215234e+27, train_score: 0.045091396024142805
# ----------------------------------------
# WantWorkDatabase
# shape: (12891, 210)
# test_score: -6.147655438799927e+27, train_score: 0.05739833744743217
# ----------------------------------------
# HaveWorkedPlatform
# shape: (12891, 1086)
# test_score: -1.1155929039961849e+29, train_score: -0.028379993078188726
# ----------------------------------------
# WantWorkPlatform
# shape: (12891, 1203)
# test_score: -1.5606627506812355e+29, train_score: -0.07732845967551571
# ----------------------------------------
# IDE
# shape: (12891, 2221)
# test_score: -6.90787264478387e+29, train_score: -1.4436184826428766
# ----------------------------------------
# AuditoryEnvironment
# shape: (12891, 6)
# test_score: 0.005314605519194493, train_score: 0.006293924216147162
# ----------------------------------------
# Methodology
# shape: (12891, 477)
# test_score: -1.7888175794478035e+28, train_score: 0.07458423130903169
# ----------------------------------------
# VersionControl
# shape: (12891, 10)
# test_score: 0.010072794722919887, train_score: 0.01653301827373932
# ----------------------------------------
# CheckInCode
# shape: (12891, 6)
# test_score: 0.00650308059166671, train_score: 0.005357276035922287
# ----------------------------------------
# ShipIt
# shape: (12891, 5)
# test_score: 0.013682922483082227, train_score: 0.015051809540650885
# ----------------------------------------
# OtherPeoplesCode
# shape: (12891, 5)
# test_score: 0.01718420230965012, train_score: 0.013251053765808374
# ----------------------------------------
# ProjectManagement
# shape: (12891, 5)
# test_score: 0.0032736346915878123, train_score: 0.0022638833026210614
# ----------------------------------------
# EnjoyDebugging
# shape: (12891, 5)
# test_score: 0.003032820126396163, train_score: 0.0030597621156994714
# ----------------------------------------
# InTheZone
# shape: (12891, 5)
# test_score: 0.016768819666513668, train_score: 0.015220703469129182
# ----------------------------------------
# DifficultCommunication
# shape: (12891, 5)
# test_score: 0.012774577461563075, train_score: 0.014619489957782283
# ----------------------------------------
# CollaborateRemote
# shape: (12891, 5)
# test_score: 0.004040118497498635, train_score: 0.002208887342171617
# ----------------------------------------
# MetricAssess
# shape: (12891, 1289)
# test_score: -1.81060886585282e+29, train_score: -0.7530167468183404
# ----------------------------------------
# EquipmentSatisfiedMonitors
# shape: (12891, 5)
# test_score: 0.010138339349311964, train_score: 0.00755173372261686
# ----------------------------------------
# EquipmentSatisfiedCPU
# shape: (12891, 5)
# test_score: 0.006285512217622968, train_score: 0.007594030848352751
# ----------------------------------------
# EquipmentSatisfiedRAM
# shape: (12891, 5)
# test_score: 0.005350276682140165, train_score: 0.005580363788673992
# ----------------------------------------
# EquipmentSatisfiedStorage
# shape: (12891, 5)
# test_score: 0.003527537620060528, train_score: 0.004329318371748436
# ----------------------------------------
# EquipmentSatisfiedRW
# shape: (12891, 5)
# test_score: 0.009173304588635744, train_score: 0.00923415765678337
# ----------------------------------------
# InfluenceInternet
# shape: (12891, 5)
# test_score: 0.008170895644044385, train_score: 0.005344883664710753
# ----------------------------------------
# InfluenceWorkstation
# shape: (12891, 5)
# test_score: 0.010980863779999073, train_score: 0.009251020257458387
# ----------------------------------------
# InfluenceHardware
# shape: (12891, 5)
# test_score: 0.0026589026904504376, train_score: 0.005013225992528625
# ----------------------------------------
# InfluenceServers
# shape: (12891, 5)
# test_score: 0.0034439051505026352, train_score: 0.005597886896735127
# ----------------------------------------
# InfluenceTechStack
# shape: (12891, 5)
# test_score: 0.006101152179882607, train_score: 0.008222537334864222
# ----------------------------------------
# InfluenceDeptTech
# shape: (12891, 5)
# test_score: 0.024714903190057536, train_score: 0.019952229626111206
# ----------------------------------------
# InfluenceVizTools
# shape: (12891, 5)
# test_score: 0.006969344996064497, train_score: 0.010678218465234868
# ----------------------------------------
# InfluenceDatabase
# shape: (12891, 5)
# test_score: 0.006198160209387904, train_score: 0.006798907823754363
# ----------------------------------------
# InfluenceCloud
# shape: (12891, 5)
# test_score: 0.008364610705327014, train_score: 0.009426690478443134
# ----------------------------------------
# InfluenceConsultants
# shape: (12891, 5)
# test_score: 0.003803368428473619, train_score: 0.010815186296769919
# ----------------------------------------
# InfluenceRecruitment
# shape: (12891, 5)
# test_score: 0.0025973531050237364, train_score: 0.004502489911869634
# ----------------------------------------
# InfluenceCommunication
# shape: (12891, 5)
# test_score: 0.0032767513323039843, train_score: 0.006464156238495278
# ----------------------------------------
# StackOverflowDescribes
# shape: (12891, 5)
# test_score: 0.006008189556179988, train_score: 0.010804787336864075
# ----------------------------------------
# StackOverflowDevices
# shape: (12891, 32)
# test_score: 0.01862906657004404, train_score: 0.03542358508702115
# ----------------------------------------
# StackOverflowFoundAnswer
# shape: (12891, 5)
# test_score: 0.01568142250414084, train_score: 0.019627530576013963
# ----------------------------------------
# StackOverflowCopiedCode
# shape: (12891, 5)
# test_score: 0.03699140020104186, train_score: 0.04204681639508112
# ----------------------------------------
# StackOverflowJobListing
# shape: (12891, 5)
# test_score: 0.01397324371378561, train_score: 0.01852876841169815
# ----------------------------------------
# StackOverflowCompanyPage
# shape: (12891, 5)
# test_score: 0.013656669479571781, train_score: 0.013020832483722766
# ----------------------------------------
# StackOverflowJobSearch
# shape: (12891, 5)
# test_score: 0.01092774206555891, train_score: 0.012525877961585996
# ----------------------------------------
# StackOverflowNewQuestion
# shape: (12891, 5)
# test_score: 0.01741131449541189, train_score: 0.014110107931745164
# ----------------------------------------
# StackOverflowAnswer
# shape: (12891, 5)
# test_score: 0.007647584766043547, train_score: 0.010225557036926847
# ----------------------------------------
# StackOverflowMetaChat
# shape: (12891, 5)
# test_score: 0.011152888341680045, train_score: 0.010984757950813107
# ----------------------------------------
# StackOverflowAdsRelevant
# shape: (12891, 5)
# test_score: 0.0035021420766994105, train_score: 0.007264592215288301
# ----------------------------------------
# StackOverflowAdsDistracting
# shape: (12891, 5)
# test_score: 0.00495330552609019, train_score: 0.010247358068994461
# ----------------------------------------
# StackOverflowModeration
# shape: (12891, 5)
# test_score: 0.006610164436013477, train_score: 0.012066898161880668
# ----------------------------------------
# StackOverflowCommunity
# shape: (12891, 5)
# test_score: 0.02016983637725922, train_score: 0.014356307232091803
# ----------------------------------------
# StackOverflowHelpful
# shape: (12891, 5)
# test_score: 0.01396088313618915, train_score: 0.012978908134480882
# ----------------------------------------
# StackOverflowBetter
# shape: (12891, 5)
# test_score: 0.009390536736195942, train_score: 0.010785354820559978
# ----------------------------------------
# StackOverflowWhatDo
# shape: (12891, 5)
# test_score: 0.006180239226589834, train_score: 0.01149144330948737
# ----------------------------------------
# StackOverflowMakeMoney
# shape: (12891, 5)
# test_score: 0.00617275047883703, train_score: 0.010522676755073346
# ----------------------------------------
# Gender
# shape: (12891, 19)
# test_score: 1.3587170536011328e-05, train_score: 0.008618156069942318
# ----------------------------------------
# HighestEducationParents
# shape: (12891, 10)
# test_score: 0.011432648891307795, train_score: 0.030574280762974193
# ----------------------------------------
# Race
# shape: (12891, 55)
# test_score: 0.06349849905100025, train_score: 0.06561597617228043
# ----------------------------------------
# SurveyLong
# shape: (12891, 5)
# test_score: 0.03297184650898477, train_score: 0.03257472814823148
# ----------------------------------------
# QuestionsInteresting
# shape: (12891, 5)
# test_score: 0.011268393328435988, train_score: 0.013669800908288177
# ----------------------------------------
# QuestionsConfusing
# shape: (12891, 5)
# test_score: 0.0222046313266695, train_score: 0.025080474073352566
# ----------------------------------------
# InterestedAnswers
# shape: (12891, 5)
# test_score: 0.00579591348183095, train_score: 0.009654643178323874
# ----------------------------------------

# %%
rank_test.sort(reverse=True)
rank_train.sort(reverse=True)

# %%
rank_test[:10]
# Out:
# [[0.4167738538485196, 'Currency'],
#  [0.20301667135459334, 'YearsCodedJob'],
#  [0.17681542205634249, 'YearsProgram'],
#  [0.10317553831646353, 'CompanyType'],
#  [0.06349849905100025, 'Race'],
#  [0.059509865901402725, 'University'],
#  [0.05663789325191737, 'Overpaid'],
#  [0.05192326010693504, 'CompanySize'],
#  [0.038759220445147125, 'ImportantHiringPMExp'],
#  [0.03699140020104186, 'StackOverflowCopiedCode']]

# %%
rank_train[:10]
# Out:
# [[0.570935821010838, 'Country'],
#  [0.4339837071598497, 'Currency'],
#  [0.2311629385849997, 'YearsCodedJob'],
#  [0.20201034255966033, 'YearsProgram'],
#  [0.10236362926073217, 'CompanyType'],
#  [0.08636347969307256, 'EducationTypes'],
#  [0.07458423130903169, 'Methodology'],
#  [0.07184415657926957, 'JobProfile'],
#  [0.06561597617228043, 'Race'],
#  [0.05739833744743217, 'WantWorkDatabase']]

# %%
num_features = [1, 2, 3, 4, 5, 10, 20, 50, 100, len(rank_test)]

# %%
test_scores = []
train_scores = []
for num in num_features:
    features = []
    for i in range(num):
        features.append(rank_test[i][1])
    X = pd.DataFrame()
    for feature in features:
        if feature in numeric_df_dict:
            X = pd.concat([X, numeric_df_dict[feature]], axis=1)
        elif feature in categorized_df_dict:
            X = pd.concat([X, categorized_df_dict[feature]], axis=1)
        else:
            print(f"{feature} not in numeric_df_dict or categorized_df_dict!!!")
            
    test_score, train_score = check_result(num, X, y)
    test_scores.append([test_score, num])
    train_scores.append([train_score, num])
# Out:
# 1
# shape: (12891, 17)
# test_score: 0.4167738538485196, train_score: 0.4339837071598497
# ----------------------------------------
# 2
# shape: (12891, 38)
# test_score: 0.5533608651193768, train_score: 0.5717896815799879
# ----------------------------------------
# 3
# shape: (12891, 59)
# test_score: 0.5579702570388851, train_score: 0.5791724605692948
# ----------------------------------------
# 4
# shape: (12891, 70)
# test_score: 0.5907981786641967, train_score: 0.6093640430709086
# ----------------------------------------
# 5
# shape: (12891, 125)
# test_score: -2.8933110678915737e+24, train_score: 0.6156692302749206
# ----------------------------------------
# 10
# shape: (12891, 154)
# test_score: -1.3860895637801805e+25, train_score: 0.655538856055528
# ----------------------------------------
# 20
# shape: (12891, 211)
# test_score: -6.550066498594873e+23, train_score: 0.6745769563524515
# ----------------------------------------
# 50
# shape: (12891, 409)
# test_score: -2.447397800897439e+26, train_score: 0.6949489154160645
# ----------------------------------------
# 100
# shape: (12891, 661)
# test_score: -4.3798824048001777e+24, train_score: 0.7110935971432895
# ----------------------------------------
# 145
# shape: (12891, 21248)
# test_score: -0.42987120036592863, train_score: 1.0
# ----------------------------------------

# %%
num_features = list(range(len(rank_test), len(rank_test)-10, -1))

# %%
test_scores = []
train_scores = []
for num in num_features:
    features = []
    for i in range(num):
        features.append(rank_test[i][1])
    X = pd.DataFrame()
    for feature in features:
        if feature in numeric_df_dict:
            X = pd.concat([X, numeric_df_dict[feature]], axis=1)
        elif feature in categorized_df_dict:
            X = pd.concat([X, categorized_df_dict[feature]], axis=1)
        else:
            print(f"{feature} not in numeric_df_dict or categorized_df_dict!!!")
            
    test_score, train_score = check_result(num, X, y)
    test_scores.append([test_score, num])
    train_scores.append([train_score, num])
# Out:
# 145
# shape: (12891, 21248)

# %% [markdown]
# ## Use my get dummies function

# %%
# import 2017 dataset
df = import_data('./survey_results_public_2017.csv', ['Respondent', 'ExpectedSalary'])
label_to_predict = 'Salary'
test_with_numeric_columns(df, label_to_predict)
# Out:
# Imported dataframe shape:  (51392, 154)
# Df now has shape of (51392, 152)
# Importing df with shape of (51392, 152) is complete!!!
# Dataframe shape with only numeric value columns:  (51392, 5)
# Dataframe shape when nan value is dropped in label(Salary):  (12891, 5)
# The r-squared score for the model using only quantitative variables was 0.04072431792894726 on 3868 values.

# %%
df = df.dropna(subset=[label_to_predict], axis=0)
Xs = df.drop(label_to_predict, axis=1)
Xs = Xs.dropna(how='all', axis=1)
y = df[label_to_predict]
print(f"df shape: {df.shape}")
print(f"Xs shape: {Xs.shape}")
print(f"y shape: {y.shape}")
# Out:
# df shape: (12891, 152)
# Xs shape: (12891, 145)
# y shape: (12891,)

# %%
numeric_df_dict, numeric_df_names_list = get_numeric_dict(Xs)
multiple_value_columns = get_multiple_value_columns(Xs) # if use my method to get 
categorized_df_dict, categorized_df_names_list = get_dummy_dict(Xs, multiple_value_columns)
# Out:
# Numeric columns from this df:  4
# Object columns from this df:  141

# %%
assert Xs.shape[1] == len(numeric_df_dict)+len(categorized_df_dict)
assert Xs.shape[1] == len(categorized_df_names_list)+len(numeric_df_names_list)

# %%
def check_result(col, df, y):
    print(col)
    print(f"shape: {df.shape}")
    
    X = df      
    #Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state=42) 
    
    model = train_model(X_train, y_train)

    #Predict and score the model
    y_test_preds = model.predict(X_test) 
    y_train_preds = model.predict(X_train)
    test_score = r2_score(y_test, y_test_preds)
    train_score = r2_score(y_train, y_train_preds)
    print(f"test_score: {test_score}, train_score: {train_score}")
    print('-'*40)
    
    return test_score, train_score

# %%
# rank every columns prediction r2score
rank_test = []
rank_train = []

for col, df_num in numeric_df_dict.items():
    test_score, train_score = check_result(col, df_num.values.reshape(-1,1), y)
    
    rank_test.append([test_score, col])
    rank_train.append([train_score, col])

for col, df_obj in categorized_df_dict.items():   
    test_score, train_score = check_result(col, df_obj, y)
    
    rank_test.append([test_score, col])
    rank_train.append([train_score, col])
# Out:
# CareerSatisfaction
# shape: (12891, 1)
# test_score: 0.02440744353670876, train_score: 0.02511874806277581
# ----------------------------------------
# JobSatisfaction
# shape: (12891, 1)
# test_score: 0.015714880014184307, train_score: 0.013990287390995837
# ----------------------------------------
# HoursPerWeek
# shape: (12891, 1)
# test_score: 0.008116429443099316, train_score: 0.005353632681996512
# ----------------------------------------
# StackOverflowSatisfaction
# shape: (12891, 1)
# test_score: 0.005130504975913497, train_score: 0.005559666137063934
# ----------------------------------------
# Professional
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ProgramHobby
# shape: (12891, 4)
# test_score: 0.0005247655454900801, train_score: 0.0057765601272673495
# ----------------------------------------
# Country
# shape: (12891, 136)
# test_score: -7.709702341110363e+25, train_score: 0.570935821010838
# ----------------------------------------
# University
# shape: (12891, 4)
# test_score: 0.059509865901402725, train_score: 0.0544224472514756
# ----------------------------------------
# EmploymentStatus
# shape: (12891, 2)
# test_score: 0.019032652112208392, train_score: 0.019680973264939228
# ----------------------------------------
# FormalEducation
# shape: (12891, 9)
# test_score: 0.016781040731313368, train_score: 0.02146004172634286
# ----------------------------------------
# MajorUndergrad
# shape: (12891, 16)
# test_score: 0.033774400959650674, train_score: 0.04188434138419572
# ----------------------------------------
# HomeRemote
# shape: (12891, 7)
# test_score: 0.0339319541374008, train_score: 0.04134497377080071
# ----------------------------------------
# CompanySize
# shape: (12891, 10)
# test_score: 0.05192326010693504, train_score: 0.055556882964653886
# ----------------------------------------
# CompanyType
# shape: (12891, 11)
# test_score: 0.10317553831646353, train_score: 0.10236362926073217
# ----------------------------------------
# YearsProgram
# shape: (12891, 21)
# test_score: 0.17681542205634249, train_score: 0.20201034255966033
# ----------------------------------------
# YearsCodedJob
# shape: (12891, 21)
# test_score: 0.20301667135459334, train_score: 0.2311629385849997
# ----------------------------------------
# YearsCodedJobPast
# shape: (12891, 4)
# test_score: -2.280556701905745e-05, train_score: 0.0006237932263345458
# ----------------------------------------
# DeveloperType
# shape: (12891, 27)
# test_score: 0.023596096345929962, train_score: 0.0410457307088371
# ----------------------------------------
# WebDeveloperType
# shape: (12891, 3)
# test_score: 0.0017131740201840051, train_score: 0.0027155256767170677
# ----------------------------------------
# MobileDeveloperType
# shape: (12891, 6)
# test_score: 0.00039945517791284413, train_score: 0.007397909806841074
# ----------------------------------------
# ExCoderReturn
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ExCoder10Years
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# ExCoderSkills
# shape: (12891, 1)
# test_score: -1.858952728239771e-05, train_score: 0.0
# ----------------------------------------
# PronounceGIF
# shape: (12891, 4)
# test_score: 0.019270992154200695, train_score: 0.026805212474406592
# ----------------------------------------
# ProblemSolving
# shape: (12891, 5)
# test_score: 0.0058759198066533624, train_score: 0.005640193683399519
# ----------------------------------------
# BuildingThings
# shape: (12891, 5)
# test_score: 0.008689107131503837, train_score: 0.009525815942812543
# ----------------------------------------
# LearningNewTech
# shape: (12891, 5)
# test_score: -0.0014676983983392677, train_score: 0.0023255682404840217
# ----------------------------------------
# BoringDetails
# shape: (12891, 5)
# test_score: 0.003825684214371239, train_score: 0.00727594475588933
# ----------------------------------------
# JobSecurity
# shape: (12891, 5)
# test_score: -0.002452215567662952, train_score: 0.0011779576819969106
# ----------------------------------------
# DiversityImportant
# shape: (12891, 5)
# test_score: 0.0008939673336939569, train_score: 0.008701883033150004
# ----------------------------------------
# AnnoyingUI
# shape: (12891, 5)
# test_score: 0.01081481111540128, train_score: 0.008403714557044917
# ----------------------------------------
# FriendsDevelopers
# shape: (12891, 5)
# test_score: 0.0012467712615621407, train_score: 0.004213833479101758
# ----------------------------------------
# RightWrongWay
# shape: (12891, 5)
# test_score: 0.026071512406958264, train_score: 0.03192385119710861
# ----------------------------------------
# UnderstandComputers
# shape: (12891, 5)
# test_score: 0.016158598188965367, train_score: 0.01793735269493324
# ----------------------------------------
# SeriousWork
# shape: (12891, 5)
# test_score: -0.0009396045912348772, train_score: 0.0033597345113587362
# ----------------------------------------
# InvestTimeTools
# shape: (12891, 5)
# test_score: -0.00011516121709198579, train_score: 0.0022920127629589837
# ----------------------------------------
# WorkPayCare
# shape: (12891, 5)
# test_score: -0.0005343718528225683, train_score: 0.0013682412808148081
# ----------------------------------------
# KinshipDevelopers
# shape: (12891, 5)
# test_score: 0.0009581774258983211, train_score: 0.004361760118558711
# ----------------------------------------
# ChallengeMyself
# shape: (12891, 5)
# test_score: 0.0015011754323820403, train_score: 0.0017763697178764248
# ----------------------------------------
# CompetePeers
# shape: (12891, 5)
# test_score: 0.007874348428628886, train_score: 0.007937316620847734
# ----------------------------------------
# ChangeWorld
# shape: (12891, 5)
# test_score: 0.0031183890202441944, train_score: 0.003704523656501313
# ----------------------------------------
# JobSeekingStatus
# shape: (12891, 3)
# test_score: 0.016917486655911085, train_score: 0.015133338165649435
# ----------------------------------------
# LastNewJob
# shape: (12891, 5)
# test_score: 0.024080623382848998, train_score: 0.02844492138851551
# ----------------------------------------
# AssessJobIndustry
# shape: (12891, 5)
# test_score: 0.009368675949188332, train_score: 0.005525568403546011
# ----------------------------------------
# AssessJobRole
# shape: (12891, 5)
# test_score: 0.007173911729732474, train_score: 0.0044060727843449055
# ----------------------------------------
# AssessJobExp
# shape: (12891, 5)
# test_score: 0.005293454415994825, train_score: 0.002041276172576545
# ----------------------------------------
# AssessJobDept
# shape: (12891, 5)
# test_score: 0.005823494223578418, train_score: 0.0026171456393433434
# ----------------------------------------
# AssessJobTech
# shape: (12891, 5)
# test_score: 0.007048146730017857, train_score: 0.002553998188946527
# ----------------------------------------
# AssessJobProjects
# shape: (12891, 5)
# test_score: 0.003995470924941014, train_score: 0.001621303396405649
# ----------------------------------------
# AssessJobCompensation
# shape: (12891, 5)
# test_score: 0.009219721479803322, train_score: 0.015193122148975502
# ----------------------------------------
# AssessJobOffice
# shape: (12891, 5)
# test_score: 0.0037333032951430978, train_score: 0.0019018038568759943
# ----------------------------------------
# AssessJobCommute
# shape: (12891, 5)
# test_score: 0.025785821726042046, train_score: 0.02302210357972545
# ----------------------------------------
# AssessJobRemote
# shape: (12891, 5)
# test_score: 0.007809722842033406, train_score: 0.006414287557596876
# ----------------------------------------
# AssessJobLeaders
# shape: (12891, 5)
# test_score: 0.00481179625421102, train_score: 0.001789923139501548
# ----------------------------------------
# AssessJobProfDevel
# shape: (12891, 5)
# test_score: 0.008123150881943264, train_score: 0.00896107394472001
# ----------------------------------------
# AssessJobDiversity
# shape: (12891, 5)
# test_score: 0.005869003987272636, train_score: 0.003278075731828034
# ----------------------------------------
# AssessJobProduct
# shape: (12891, 5)
# test_score: 0.003116889684548485, train_score: 0.0017756857645890856
# ----------------------------------------
# AssessJobFinances
# shape: (12891, 5)
# test_score: 0.004925577798540082, train_score: 0.0034662115815516925
# ----------------------------------------
# ImportantBenefits
# shape: (12891, 33)
# test_score: 0.0709689802747091, train_score: 0.10011009144103578
# ----------------------------------------
# ClickyKeys
# shape: (12891, 2)
# test_score: 0.0009173493809646605, train_score: 0.0009201719340772296
# ----------------------------------------
# JobProfile
# shape: (12891, 37)
# test_score: 0.07310429022915554, train_score: 0.06828447343954602
# ----------------------------------------
# ResumePrompted
# shape: (12891, 8)
# test_score: 0.007348218600445988, train_score: 0.009252590135821137
# ----------------------------------------
# LearnedHiring
# shape: (12891, 8)
# test_score: 0.010394993173299616, train_score: 0.013904729404609073
# ----------------------------------------
# ImportantHiringAlgorithms
# shape: (12891, 5)
# test_score: 0.006151073898474579, train_score: 0.00920158875427457
# ----------------------------------------
# ImportantHiringTechExp
# shape: (12891, 5)
# test_score: 0.016662468584125234, train_score: 0.01812199910832213
# ----------------------------------------
# ImportantHiringCommunication
# shape: (12891, 5)
# test_score: 0.026928444070211, train_score: 0.02748299420203615
# ----------------------------------------
# ImportantHiringOpenSource
# shape: (12891, 5)
# test_score: 0.00825146519741693, train_score: 0.005592226389724564
# ----------------------------------------
# ImportantHiringPMExp
# shape: (12891, 5)
# test_score: 0.038759220445147125, train_score: 0.040381960782815196
# ----------------------------------------
# ImportantHiringCompanies
# shape: (12891, 5)
# test_score: 0.0025991960236794176, train_score: 0.004412812375864439
# ----------------------------------------
# ImportantHiringTitles
# shape: (12891, 5)
# test_score: 0.007039877690634522, train_score: 0.010887316147601522
# ----------------------------------------
# ImportantHiringEducation
# shape: (12891, 5)
# test_score: 0.003565683805979991, train_score: 0.004483274912324364
# ----------------------------------------
# ImportantHiringRep
# shape: (12891, 5)
# test_score: 0.0170503305175268, train_score: 0.012779527210053154
# ----------------------------------------
# ImportantHiringGettingThingsDone
# shape: (12891, 5)
# test_score: 0.03299409292136546, train_score: 0.04165277292225322
# ----------------------------------------
# Currency
# shape: (12891, 17)
# test_score: 0.4167738538485196, train_score: 0.4339837071598497
# ----------------------------------------
# Overpaid
# shape: (12891, 5)
# test_score: 0.05663789325191737, train_score: 0.049559190807826115
# ----------------------------------------
# TabsSpaces
# shape: (12891, 3)
# test_score: 0.032320097166636086, train_score: 0.04455488365921256
# ----------------------------------------
# EducationImportant
# shape: (12891, 5)
# test_score: 5.201985759994976e-05, train_score: 0.001228346020224147
# ----------------------------------------
# EducationTypes
# shape: (12891, 17)
# test_score: 0.04588677182888434, train_score: 0.05332324355066709
# ----------------------------------------
# SelfTaughtTypes
# shape: (12891, 21)
# test_score: 0.022144951882387964, train_score: 0.027625306273061923
# ----------------------------------------
# TimeAfterBootcamp
# shape: (12891, 9)
# test_score: 0.0026799662850353068, train_score: 0.004903854787498441
# ----------------------------------------
# CousinEducation
# shape: (12891, 24)
# test_score: 0.021156120437592074, train_score: 0.02041665807827897
# ----------------------------------------
# WorkStart
# shape: (12891, 24)
# test_score: 0.01632459814083964, train_score: 0.0245959558867076
# ----------------------------------------
# HaveWorkedLanguage
# shape: (12891, 68)
# test_score: 0.06473857270436212, train_score: 0.07301978977600854
# ----------------------------------------
# WantWorkLanguage
# shape: (12891, 69)
# test_score: 0.04218761137502414, train_score: 0.04930963860940918
# ----------------------------------------
# HaveWorkedFramework
# shape: (12891, 17)
# test_score: 0.0231102684478387, train_score: 0.019071483304514247
# ----------------------------------------
# WantWorkFramework
# shape: (12891, 17)
# test_score: 0.0227705471130778, train_score: 0.022730693709255845
# ----------------------------------------
# HaveWorkedDatabase
# shape: (12891, 15)
# test_score: 0.03421260902954826, train_score: 0.028820407785287605
# ----------------------------------------
# WantWorkDatabase
# shape: (12891, 15)
# test_score: 0.031630608863732035, train_score: 0.040513914172822796
# ----------------------------------------
# HaveWorkedPlatform
# shape: (12891, 29)
# test_score: 0.046886041425607705, train_score: 0.06489831403472701
# ----------------------------------------
# WantWorkPlatform
# shape: (12891, 29)
# test_score: 0.03024473440997566, train_score: 0.041274656362228046
# ----------------------------------------
# IDE
# shape: (12891, 43)
# test_score: 0.07708971568958778, train_score: 0.08282596256489372
# ----------------------------------------
# AuditoryEnvironment
# shape: (12891, 6)
# test_score: 0.005314605519194493, train_score: 0.006293924216147162
# ----------------------------------------
# Methodology
# shape: (12891, 21)
# test_score: 0.022414532094782502, train_score: 0.03709442117880246
# ----------------------------------------
# VersionControl
# shape: (12891, 10)
# test_score: 0.010072794722919887, train_score: 0.01653301827373932
# ----------------------------------------
# CheckInCode
# shape: (12891, 6)
# test_score: 0.00650308059166671, train_score: 0.005357276035922287
# ----------------------------------------
# ShipIt
# shape: (12891, 5)
# test_score: 0.013682922483082227, train_score: 0.015051809540650885
# ----------------------------------------
# OtherPeoplesCode
# shape: (12891, 5)
# test_score: 0.01718420230965012, train_score: 0.013251053765808374
# ----------------------------------------
# ProjectManagement
# shape: (12891, 5)
# test_score: 0.0032736346915878123, train_score: 0.0022638833026210614
# ----------------------------------------
# EnjoyDebugging
# shape: (12891, 5)
# test_score: 0.003032820126396163, train_score: 0.0030597621156994714
# ----------------------------------------
# InTheZone
# shape: (12891, 5)
# test_score: 0.016768819666513668, train_score: 0.015220703469129182
# ----------------------------------------
# DifficultCommunication
# shape: (12891, 5)
# test_score: 0.012774577461563075, train_score: 0.014619489957782283
# ----------------------------------------
# CollaborateRemote
# shape: (12891, 5)
# test_score: 0.004040118497498635, train_score: 0.002208887342171617
# ----------------------------------------
# MetricAssess
# shape: (12891, 25)
# test_score: 0.03556732127453477, train_score: 0.05454370659831731
# ----------------------------------------
# EquipmentSatisfiedMonitors
# shape: (12891, 5)
# test_score: 0.010138339349311964, train_score: 0.00755173372261686
# ----------------------------------------
# EquipmentSatisfiedCPU
# shape: (12891, 5)
# test_score: 0.006285512217622968, train_score: 0.007594030848352751
# ----------------------------------------
# EquipmentSatisfiedRAM
# shape: (12891, 5)
# test_score: 0.005350276682140165, train_score: 0.005580363788673992
# ----------------------------------------
# EquipmentSatisfiedStorage
# shape: (12891, 5)
# test_score: 0.003527537620060528, train_score: 0.004329318371748436
# ----------------------------------------
# EquipmentSatisfiedRW
# shape: (12891, 5)
# test_score: 0.009173304588635744, train_score: 0.00923415765678337
# ----------------------------------------
# InfluenceInternet
# shape: (12891, 5)
# test_score: 0.008170895644044385, train_score: 0.005344883664710753
# ----------------------------------------
# InfluenceWorkstation
# shape: (12891, 5)
# test_score: 0.010980863779999073, train_score: 0.009251020257458387
# ----------------------------------------
# InfluenceHardware
# shape: (12891, 5)
# test_score: 0.0026589026904504376, train_score: 0.005013225992528625
# ----------------------------------------
# InfluenceServers
# shape: (12891, 5)
# test_score: 0.0034439051505026352, train_score: 0.005597886896735127
# ----------------------------------------
# InfluenceTechStack
# shape: (12891, 5)
# test_score: 0.006101152179882607, train_score: 0.008222537334864222
# ----------------------------------------
# InfluenceDeptTech
# shape: (12891, 5)
# test_score: 0.024714903190057536, train_score: 0.019952229626111206
# ----------------------------------------
# InfluenceVizTools
# shape: (12891, 5)
# test_score: 0.006969344996064497, train_score: 0.010678218465234868
# ----------------------------------------
# InfluenceDatabase
# shape: (12891, 5)
# test_score: 0.006198160209387904, train_score: 0.006798907823754363
# ----------------------------------------
# InfluenceCloud
# shape: (12891, 5)
# test_score: 0.008364610705327014, train_score: 0.009426690478443134
# ----------------------------------------
# InfluenceConsultants
# shape: (12891, 5)
# test_score: 0.003803368428473619, train_score: 0.010815186296769919
# ----------------------------------------
# InfluenceRecruitment
# shape: (12891, 5)
# test_score: 0.0025973531050237364, train_score: 0.004502489911869634
# ----------------------------------------
# InfluenceCommunication
# shape: (12891, 5)
# test_score: 0.0032767513323039843, train_score: 0.006464156238495278
# ----------------------------------------
# StackOverflowDescribes
# shape: (12891, 5)
# test_score: 0.006008189556179988, train_score: 0.010804787336864075
# ----------------------------------------
# StackOverflowDevices
# shape: (12891, 10)
# test_score: 0.02270793057301923, train_score: 0.030310718563529515
# ----------------------------------------
# StackOverflowFoundAnswer
# shape: (12891, 5)
# test_score: 0.01568142250414084, train_score: 0.019627530576013963
# ----------------------------------------
# StackOverflowCopiedCode
# shape: (12891, 5)
# test_score: 0.03699140020104186, train_score: 0.04204681639508112
# ----------------------------------------
# StackOverflowJobListing
# shape: (12891, 5)
# test_score: 0.01397324371378561, train_score: 0.01852876841169815
# ----------------------------------------
# StackOverflowCompanyPage
# shape: (12891, 5)
# test_score: 0.013656669479571781, train_score: 0.013020832483722766
# ----------------------------------------
# StackOverflowJobSearch
# shape: (12891, 5)
# test_score: 0.01092774206555891, train_score: 0.012525877961585996
# ----------------------------------------
# StackOverflowNewQuestion
# shape: (12891, 5)
# test_score: 0.01741131449541189, train_score: 0.014110107931745164
# ----------------------------------------
# StackOverflowAnswer
# shape: (12891, 5)
# test_score: 0.007647584766043547, train_score: 0.010225557036926847
# ----------------------------------------
# StackOverflowMetaChat
# shape: (12891, 5)
# test_score: 0.011152888341680045, train_score: 0.010984757950813107
# ----------------------------------------
# StackOverflowAdsRelevant
# shape: (12891, 5)
# test_score: 0.0035021420766994105, train_score: 0.007264592215288301
# ----------------------------------------
# StackOverflowAdsDistracting
# shape: (12891, 5)
# test_score: 0.00495330552609019, train_score: 0.010247358068994461
# ----------------------------------------
# StackOverflowModeration
# shape: (12891, 5)
# test_score: 0.006610164436013477, train_score: 0.012066898161880668
# ----------------------------------------
# StackOverflowCommunity
# shape: (12891, 5)
# test_score: 0.02016983637725922, train_score: 0.014356307232091803
# ----------------------------------------
# StackOverflowHelpful
# shape: (12891, 5)
# test_score: 0.01396088313618915, train_score: 0.012978908134480882
# ----------------------------------------
# StackOverflowBetter
# shape: (12891, 5)
# test_score: 0.009390536736195942, train_score: 0.010785354820559978
# ----------------------------------------
# StackOverflowWhatDo
# shape: (12891, 5)
# test_score: 0.006180239226589834, train_score: 0.01149144330948737
# ----------------------------------------
# StackOverflowMakeMoney
# shape: (12891, 5)
# test_score: 0.00617275047883703, train_score: 0.010522676755073346
# ----------------------------------------
# Gender
# shape: (12891, 9)
# test_score: 0.001631122135007046, train_score: 0.007860579827056347
# ----------------------------------------
# HighestEducationParents
# shape: (12891, 10)
# test_score: 0.011432648891307795, train_score: 0.030574280762974193
# ----------------------------------------
# Race
# shape: (12891, 17)
# test_score: 0.06621110184471446, train_score: 0.06235007357219924
# ----------------------------------------
# SurveyLong
# shape: (12891, 5)
# test_score: 0.03297184650898477, train_score: 0.03257472814823148
# ----------------------------------------
# QuestionsInteresting
# shape: (12891, 5)
# test_score: 0.011268393328435988, train_score: 0.013669800908288177
# ----------------------------------------
# QuestionsConfusing
# shape: (12891, 5)
# test_score: 0.0222046313266695, train_score: 0.025080474073352566
# ----------------------------------------
# InterestedAnswers
# shape: (12891, 5)
# test_score: 0.00579591348183095, train_score: 0.009654643178323874
# ----------------------------------------

# %%
rank_test.sort(reverse=True)
rank_train.sort(reverse=True)

# %%
rank_test[:10]
# Out:
# [[0.4167738538485196, 'Currency'],
#  [0.20301667135459334, 'YearsCodedJob'],
#  [0.17681542205634249, 'YearsProgram'],
#  [0.10317553831646353, 'CompanyType'],
#  [0.07708971568958778, 'IDE'],
#  [0.07310429022915554, 'JobProfile'],
#  [0.0709689802747091, 'ImportantBenefits'],
#  [0.06621110184471446, 'Race'],
#  [0.06473857270436212, 'HaveWorkedLanguage'],
#  [0.059509865901402725, 'University']]

# %%
rank_train[:10]
# Out:
# [[0.570935821010838, 'Country'],
#  [0.4339837071598497, 'Currency'],
#  [0.2311629385849997, 'YearsCodedJob'],
#  [0.20201034255966033, 'YearsProgram'],
#  [0.10236362926073217, 'CompanyType'],
#  [0.10011009144103578, 'ImportantBenefits'],
#  [0.08282596256489372, 'IDE'],
#  [0.07301978977600854, 'HaveWorkedLanguage'],
#  [0.06828447343954602, 'JobProfile'],
#  [0.06489831403472701, 'HaveWorkedPlatform']]

# %%
# num_features = [2, 3, 4, 5, 6, 7, 8, 9, 10, 20, 50, 100, len(rank_test)]
num_features = list(range(1, len(rank_test)+1))

# %%
test_scores = []
train_scores = []
for num in num_features:
    features = []
    for i in range(num):
        features.append(rank_test[i][1])
    X = pd.DataFrame()
    for feature in features:
        if feature in numeric_df_dict:
            X = pd.concat([X, numeric_df_dict[feature]], axis=1)
        elif feature in categorized_df_dict:
            X = pd.concat([X, categorized_df_dict[feature]], axis=1)
        else:
            print(f"{feature} not in numeric_df_dict or categorized_df_dict!!!")
            
    test_score, train_score = check_result(num, X, y)
    test_scores.append([test_score, num])
    train_scores.append([train_score, num])
# Out:
# 1
# shape: (12891, 17)
# test_score: 0.4167738538485196, train_score: 0.4339837071598497
# ----------------------------------------
# 2
# shape: (12891, 38)
# test_score: 0.5533608651193768, train_score: 0.5717896815799879
# ----------------------------------------
# 3
# shape: (12891, 59)
# test_score: 0.5579702570388851, train_score: 0.5791724605692948
# ----------------------------------------
# 4
# shape: (12891, 70)
# test_score: 0.5907981786641967, train_score: 0.6093640430709086
# ----------------------------------------
# 5
# shape: (12891, 113)
# test_score: 0.6057809978127665, train_score: 0.6242068087506347
# ----------------------------------------
# 6
# shape: (12891, 150)
# test_score: 0.6094893088177588, train_score: 0.6282150322209696
# ----------------------------------------
# 7
# shape: (12891, 183)
# test_score: -5.430516754220984e+23, train_score: 0.6370699425305056
# ----------------------------------------
# 8
# shape: (12891, 200)
# test_score: -5.73748797031855e+24, train_score: 0.6406628475894767
# ----------------------------------------
# 9
# shape: (12891, 268)
# test_score: -7.805703979679218e+25, train_score: 0.6516879062629699
# ----------------------------------------
# 10
# shape: (12891, 272)
# test_score: -1.4121282631674564e+26, train_score: 0.6569482336363826
# ----------------------------------------
# 11
# shape: (12891, 277)
# test_score: -5.757309214638436e+24, train_score: 0.6749835126311592
# ----------------------------------------
# 12
# shape: (12891, 287)
# test_score: -6.084871684022864e+24, train_score: 0.6806452127031362
# ----------------------------------------
# 13
# shape: (12891, 316)
# test_score: -1.2945987043080667e+24, train_score: 0.6870760603100964
# ----------------------------------------
# 14
# shape: (12891, 333)
# test_score: -1.4111169156842516e+23, train_score: 0.6898937559001146
# ----------------------------------------
# 15
# shape: (12891, 402)
# test_score: -2.712239187007819e+18, train_score: 0.693882971618675
# ----------------------------------------
# 16
# shape: (12891, 407)
# test_score: -2.4876686945416523e+24, train_score: 0.6952754050242292
# ----------------------------------------
# 17
# shape: (12891, 412)
# test_score: -1.5232275815460808e+24, train_score: 0.6965786393290894
# ----------------------------------------
# 18
# shape: (12891, 437)
# test_score: -3.166601342708434e+24, train_score: 0.6993472748301033
# ----------------------------------------
# 19
# shape: (12891, 452)
# test_score: -4.846008870529733e+24, train_score: 0.7009400714991774
# ----------------------------------------
# 20
# shape: (12891, 459)
# test_score: -3.7539335231166577e+25, train_score: 0.7006932003351858
# ----------------------------------------
# 21
# shape: (12891, 475)
# test_score: -4.8274170172902435e+24, train_score: 0.7042327293536328
# ----------------------------------------
# 22
# shape: (12891, 480)
# test_score: -5.11564594089694e+25, train_score: 0.7049915424257011
# ----------------------------------------
# 23
# shape: (12891, 485)
# test_score: -4.282988601245319e+24, train_score: 0.7065027652574127
# ----------------------------------------
# 24
# shape: (12891, 488)
# test_score: -5.257719454819895e+24, train_score: 0.706926261988043
# ----------------------------------------
# 25
# shape: (12891, 503)
# test_score: -1.4208515247216492e+22, train_score: 0.7081639605819123
# ----------------------------------------
# 26
# shape: (12891, 532)
# test_score: -7.530065987585887e+24, train_score: 0.7094998006546915
# ----------------------------------------
# 27
# shape: (12891, 537)
# test_score: -7.663210846860253e+24, train_score: 0.7104250915288686
# ----------------------------------------
# 28
# shape: (12891, 542)
# test_score: -7.188117805969882e+24, train_score: 0.7111259968101167
# ----------------------------------------
# 29
# shape: (12891, 547)
# test_score: -5.915180513118317e+24, train_score: 0.7113974285410303
# ----------------------------------------
# 30
# shape: (12891, 552)
# test_score: -7.629156224286688e+24, train_score: 0.7127650740409726
# ----------------------------------------
# 31
# shape: (12891, 553)
# test_score: -1.2813473860236215e+25, train_score: 0.7128980444475637
# ----------------------------------------
# 32
# shape: (12891, 558)
# test_score: -9.387183302349004e+21, train_score: 0.7135008438264712
# ----------------------------------------
# 33
# shape: (12891, 585)
# test_score: -8.663376292399829e+23, train_score: 0.7152901600006161
# ----------------------------------------
# 34
# shape: (12891, 602)
# test_score: -2.1978640885429353e+24, train_score: 0.7161955246295544
# ----------------------------------------
# 35
# shape: (12891, 619)
# test_score: -1.103706950725312e+26, train_score: 0.7165804586479245
# ----------------------------------------
# 36
# shape: (12891, 629)
# test_score: -1.332105098097734e+23, train_score: 0.7176370005579942
# ----------------------------------------
# 37
# shape: (12891, 650)
# test_score: -6.901605159826379e+24, train_score: 0.7186588014141948
# ----------------------------------------
# 38
# shape: (12891, 655)
# test_score: -9.561734680147207e+24, train_score: 0.7190163527475266
# ----------------------------------------
# 39
# shape: (12891, 676)
# test_score: -6.072806268261228e+24, train_score: 0.7201560994555611
# ----------------------------------------
# 40
# shape: (12891, 700)
# test_score: -5.675611844572861e+24, train_score: 0.7211854626111447
# ----------------------------------------
# 41
# shape: (12891, 705)
# test_score: -1.7152700229922639e+25, train_score: 0.7214588992123755
# ----------------------------------------
# 42
# shape: (12891, 709)
# test_score: -1.5199992225357038e+21, train_score: 0.7219459944425923
# ----------------------------------------
# 43
# shape: (12891, 711)
# test_score: -6.866640766558376e+24, train_score: 0.723158754060048
# ----------------------------------------
# 44
# shape: (12891, 716)
# test_score: -6.057797503013468e+24, train_score: 0.7231802514878569
# ----------------------------------------
# 45
# shape: (12891, 721)
# test_score: -5.387439019275348e+23, train_score: 0.7238703588318922
# ----------------------------------------
# 46
# shape: (12891, 726)
# test_score: -5.159519641688952e+24, train_score: 0.7243943463575885
# ----------------------------------------
# 47
# shape: (12891, 729)
# test_score: -3.88355398244248e+24, train_score: 0.7244155020417522
# ----------------------------------------
# 48
# shape: (12891, 738)
# test_score: -3.191172928709059e+23, train_score: 0.7259997797272815
# ----------------------------------------
# 49
# shape: (12891, 743)
# test_score: -5.8890547326446975e+23, train_score: 0.7263900923229087
# ----------------------------------------
# 50
# shape: (12891, 748)
# test_score: -3.979132219365716e+24, train_score: 0.7265177408317718
# ----------------------------------------
# 51
# shape: (12891, 772)
# test_score: -2.6357156370275603e+24, train_score: 0.7278826515680386
# ----------------------------------------
# 52
# shape: (12891, 777)
# test_score: -1.1841141108173558e+24, train_score: 0.7281220579448088
# ----------------------------------------
# 53
# shape: (12891, 778)
# test_score: -2.499654107544711e+24, train_score: 0.7284274561091164
# ----------------------------------------
# 54
# shape: (12891, 783)
# test_score: -4.97635781582516e+24, train_score: 0.7287204148314532
# ----------------------------------------
# 55
# shape: (12891, 788)
# test_score: -1.1344830993300811e+24, train_score: 0.7289580816931831
# ----------------------------------------
# 56
# shape: (12891, 793)
# test_score: -2.226476379447851e+23, train_score: 0.7290559781455458
# ----------------------------------------
# 57
# shape: (12891, 798)
# test_score: -1.3176017085130837e+22, train_score: 0.7290760013660096
# ----------------------------------------
# 58
# shape: (12891, 803)
# test_score: -3.4036810362693195e+24, train_score: 0.7290892860061073
# ----------------------------------------
# 59
# shape: (12891, 808)
# test_score: -2.458482932361092e+24, train_score: 0.7298709216638964
# ----------------------------------------
# 60
# shape: (12891, 818)
# test_score: -1.6635926115575115e+24, train_score: 0.7275620546989
# ----------------------------------------
# 61
# shape: (12891, 823)
# test_score: -3.1142838899398767e+24, train_score: 0.7305915490669355
# ----------------------------------------
# 62
# shape: (12891, 828)
# test_score: -2.264855212035961e+25, train_score: 0.7294209133444457
# ----------------------------------------
# 63
# shape: (12891, 833)
# test_score: -2.1776874123441498e+24, train_score: 0.731287990717616
# ----------------------------------------
# 64
# shape: (12891, 838)
# test_score: -5.493449263793631e+24, train_score: 0.7313414938873333
# ----------------------------------------
# 65
# shape: (12891, 843)
# test_score: -5.696360287838561e+23, train_score: 0.7317537852318439
# ----------------------------------------
# 66
# shape: (12891, 851)
# test_score: -6.519887836391103e+22, train_score: 0.7330347733432283
# ----------------------------------------
# 67
# shape: (12891, 856)
# test_score: -9.067296563770792e+23, train_score: 0.7331841273819442
# ----------------------------------------
# 68
# shape: (12891, 866)
# test_score: -2.576298082948149e+24, train_score: 0.7340312844638066
# ----------------------------------------
# 69
# shape: (12891, 871)
# test_score: -2.3629257816254556e+24, train_score: 0.7341267302266304
# ----------------------------------------
# 70
# shape: (12891, 876)
# test_score: -6.046584888726268e+24, train_score: 0.734293654401261
# ----------------------------------------
# 71
# shape: (12891, 881)
# test_score: -1.6851775122111667e+25, train_score: 0.7346624930437075
# ----------------------------------------
# 72
# shape: (12891, 886)
# test_score: -2.8915342366174985e+24, train_score: 0.7348987498120539
# ----------------------------------------
# 73
# shape: (12891, 891)
# test_score: -7.15030460134504e+23, train_score: 0.7350473397016137
# ----------------------------------------
# 74
# shape: (12891, 896)
# test_score: -4.525971118432826e+23, train_score: 0.7351849458092056
# ----------------------------------------
# 75
# shape: (12891, 901)
# test_score: -2.0399498212291914e+23, train_score: 0.735368964174443
# ----------------------------------------
# 76
# shape: (12891, 906)
# test_score: -7.845199020737376e+22, train_score: 0.7355717506044407
# ----------------------------------------
# 77
# shape: (12891, 911)
# test_score: -2.379784790637534e+25, train_score: 0.7361208854123358
# ----------------------------------------
# 78
# shape: (12891, 912)
# test_score: -4.7180971067372115e+25, train_score: 0.7315700931550178
# ----------------------------------------
# 79
# shape: (12891, 917)
# test_score: -2.3077530495057342e+24, train_score: 0.7363627672553267
# ----------------------------------------
# 80
# shape: (12891, 922)
# test_score: -2.4855292298460844e+25, train_score: 0.7352633634192238
# ----------------------------------------
# 81
# shape: (12891, 927)
# test_score: -1.1434281880275365e+23, train_score: 0.7368492063524856
# ----------------------------------------
# 82
# shape: (12891, 935)
# test_score: -2.869855464162872e+24, train_score: 0.7372255449558716
# ----------------------------------------
# 83
# shape: (12891, 940)
# test_score: -5.357753772675395e+24, train_score: 0.7372439477385679
# ----------------------------------------
# 84
# shape: (12891, 945)
# test_score: -1.2608134009511056e+26, train_score: 0.7371044395110832
# ----------------------------------------
# 85
# shape: (12891, 950)
# test_score: -7.628480818630212e+23, train_score: 0.7376190913102814
# ----------------------------------------
# 86
# shape: (12891, 955)
# test_score: -3.439166214864564e+19, train_score: 0.7377708476879085
# ----------------------------------------
# 87
# shape: (12891, 960)
# test_score: -1.560806840812033e+25, train_score: 0.7378828363710619
# ----------------------------------------
# 88
# shape: (12891, 966)
# test_score: -4.1865489804496015e+18, train_score: 0.7384366028370716
# ----------------------------------------
# 89
# shape: (12891, 971)
# test_score: -1.1891488776752258e+25, train_score: 0.7386640122694679
# ----------------------------------------
# 90
# shape: (12891, 976)
# test_score: -2.557782485004261e+24, train_score: 0.7389593819103587
# ----------------------------------------
# 91
# shape: (12891, 981)
# test_score: -7.199927790682657e+25, train_score: 0.7379873019219061
# ----------------------------------------
# 92
# shape: (12891, 986)
# test_score: -1.9214271853491077e+24, train_score: 0.7392768310546023
# ----------------------------------------
# 93
# shape: (12891, 991)
# test_score: -6.916693175949432e+23, train_score: 0.7396122862566998
# ----------------------------------------
# 94
# shape: (12891, 996)
# test_score: -1.4903738613884974e+24, train_score: 0.739790379236682
# ----------------------------------------
# 95
# shape: (12891, 1001)
# test_score: -1.9245551355200692e+24, train_score: 0.7399223614925465
# ----------------------------------------
# 96
# shape: (12891, 1006)
# test_score: -1.7063542034033728e+22, train_score: 0.7400946022212467
# ----------------------------------------
# 97
# shape: (12891, 1011)
# test_score: -1.670540487069584e+24, train_score: 0.7401323874939176
# ----------------------------------------
# 98
# shape: (12891, 1016)
# test_score: -9.252667913242708e+24, train_score: 0.7403105570823791
# ----------------------------------------
# 99
# shape: (12891, 1021)
# test_score: -8.31614327686485e+24, train_score: 0.7404559082980668
# ----------------------------------------
# 100
# shape: (12891, 1026)
# test_score: -9.608937855305889e+23, train_score: 0.7406774538447325
# ----------------------------------------
# 101
# shape: (12891, 1032)
# test_score: -7.163375658306494e+24, train_score: 0.7408578594708339
# ----------------------------------------
# 102
# shape: (12891, 1037)
# test_score: -4.98825217424337e+24, train_score: 0.7410389585395611
# ----------------------------------------
# 103
# shape: (12891, 1038)
# test_score: -6.685840125021143e+24, train_score: 0.7411660110344642
# ----------------------------------------
# 104
# shape: (12891, 1043)
# test_score: -1.7277916440877761e+25, train_score: 0.7412065768043882
# ----------------------------------------
# 105
# shape: (12891, 1048)
# test_score: -6.936984612163925e+24, train_score: 0.7412880607589434
# ----------------------------------------
# 106
# shape: (12891, 1053)
# test_score: -1.83789709729619e+23, train_score: 0.7417251676436467
# ----------------------------------------
# 107
# shape: (12891, 1058)
# test_score: -6.942345663808692e+24, train_score: 0.7418834066516458
# ----------------------------------------
# 108
# shape: (12891, 1063)
# test_score: -3.489958969966187e+24, train_score: 0.7419216873240837
# ----------------------------------------
# 109
# shape: (12891, 1068)
# test_score: -7.608547017541284e+24, train_score: 0.7422361528111965
# ----------------------------------------
# 110
# shape: (12891, 1073)
# test_score: -4.101359542225018e+25, train_score: 0.7427013271477205
# ----------------------------------------
# 111
# shape: (12891, 1078)
# test_score: -4.486496029995856e+25, train_score: 0.7432964111168556
# ----------------------------------------
# 112
# shape: (12891, 1083)
# test_score: -1.9194752224515088e+24, train_score: 0.7436711599923536
# ----------------------------------------
# 113
# shape: (12891, 1088)
# test_score: -1.1845822649447982e+25, train_score: 0.7438928824384172
# ----------------------------------------
# 114
# shape: (12891, 1093)
# test_score: -1.9945392814791929e+24, train_score: 0.7443937486974035
# ----------------------------------------
# 115
# shape: (12891, 1098)
# test_score: -1.1750948719849187e+24, train_score: 0.7445488998133512
# ----------------------------------------
# 116
# shape: (12891, 1103)
# test_score: -1.341627435740144e+23, train_score: 0.7447276009521034
# ----------------------------------------
# 117
# shape: (12891, 1108)
# test_score: -1.494395609944568e+23, train_score: 0.7449395907926779
# ----------------------------------------
# 118
# shape: (12891, 1113)
# test_score: -9.132782798474881e+23, train_score: 0.7450926212848247
# ----------------------------------------
# 119
# shape: (12891, 1118)
# test_score: -1.186993921073027e+25, train_score: 0.7453628489416645
# ----------------------------------------
# 120
# shape: (12891, 1123)
# test_score: -1.4569377659039695e+22, train_score: 0.7456691484654548
# ----------------------------------------
# 121
# shape: (12891, 1132)
# test_score: -2.2630924348137397e+24, train_score: 0.7458199380726878
# ----------------------------------------
# 122
# shape: (12891, 1137)
# test_score: -6.46386594162658e+23, train_score: 0.746026035900232
# ----------------------------------------
# 123
# shape: (12891, 1142)
# test_score: -3.487426778405896e+24, train_score: 0.7459647581283073
# ----------------------------------------
# 124
# shape: (12891, 1147)
# test_score: -3.5124758406612777e+25, train_score: 0.7463001261691732
# ----------------------------------------
# 125
# shape: (12891, 1150)
# test_score: -5.149608628758603e+24, train_score: 0.7464047794923894
# ----------------------------------------
# 126
# shape: (12891, 1159)
# test_score: -5.933959810802754e+24, train_score: 0.7466323892713793
# ----------------------------------------
# 127
# shape: (12891, 1164)
# test_score: -6.465419011375839e+24, train_score: 0.7468486133151441
# ----------------------------------------
# 128
# shape: (12891, 1169)
# test_score: -2.441974238749599e+24, train_score: 0.7470376572346011
# ----------------------------------------
# 129
# shape: (12891, 1174)
# test_score: -1.7799900605194805e+24, train_score: 0.7470988521896766
# ----------------------------------------
# 130
# shape: (12891, 1176)
# test_score: -5.624609011823753e+24, train_score: 0.7471266151268299
# ----------------------------------------
# 131
# shape: (12891, 1181)
# test_score: -2.538669470245428e+23, train_score: 0.7473542443444361
# ----------------------------------------
# 132
# shape: (12891, 1185)
# test_score: -3.170779845873687e+23, train_score: 0.7474923237103365
# ----------------------------------------
# 133
# shape: (12891, 1191)
# test_score: -2.3419106629503682e+23, train_score: 0.747662294038685
# ----------------------------------------
# 134
# shape: (12891, 1196)
# test_score: -1.5403993057256987e+22, train_score: 0.7478249967839378
# ----------------------------------------
# 135
# shape: (12891, 1197)
# test_score: -2.7622486997523125e+23, train_score: 0.7478262519601833
# ----------------------------------------
# 136
# shape: (12891, 1198)
# test_score: -3.1198678258320096e+23, train_score: 0.7478244935621643
# ----------------------------------------
# 137
# shape: (12891, 1199)
# test_score: -2.3281603011435242e+24, train_score: 0.7477471525140987
# ----------------------------------------
# 138
# shape: (12891, 1200)
# test_score: -4.731792158093535e+23, train_score: 0.7478260154598666
# ----------------------------------------
# 139
# shape: (12891, 1204)
# test_score: -6.577004348551903e+24, train_score: 0.7474692181856044
# ----------------------------------------
# 140
# shape: (12891, 1209)
# test_score: -2.8716609290837522e+25, train_score: 0.7468773128374833
# ----------------------------------------
# 141
# shape: (12891, 1214)
# test_score: -6.264618840151325e+24, train_score: 0.7479774256491283
# ----------------------------------------
# 142
# shape: (12891, 1219)
# test_score: -1.8441373746018724e+24, train_score: 0.7482840075220818
# ----------------------------------------
# 143
# shape: (12891, 1224)
# test_score: -5.126914621982429e+23, train_score: 0.7487204310568175
# ----------------------------------------
# 144
# shape: (12891, 1229)
# test_score: -5.845549151340118e+23, train_score: 0.7489576296333288
# ----------------------------------------
# 145
# shape: (12891, 1365)
# test_score: -1.9138531130635174e+24, train_score: 0.81779312793545
# ----------------------------------------

# %% [markdown]
# # drop rows where
